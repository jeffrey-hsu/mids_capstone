# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2017-2018 school vaccination data
# - Numbers in the original document have been surpressed for <=1%, <=2%, <=5% and >=95%,>=98%,>=99%. Original file has errors with <=,  >=, and --* symbols when importing directly from .xlsx
# - The 3 raw datafiles for childcare, kindergarden, and 7th grade has been compiled manually into a csv called `raw17_18_combined.csv` with <= and >= removed and replaced with the corresponding numbers

# %%
# Import raw combined 2017-2018 school vaccination data
pertusis_1718 = pd.read_csv("Raw_Data/raw17_18_combined.csv",encoding = "ISO-8859-1")

# %%
pertusis_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  ALAMEDA         HEAD START  ALAMEDA
# 1         13417425  ALAMEDA         HEAD START  ALAMEDA
# 2         13420593  ALAMEDA         HEAD START  ALAMEDA
# 3         13417441  ALAMEDA            PRIVATE  ALAMEDA
# 4          6151211  ALAMEDA            PRIVATE  ALAMEDA
#
#                                        FACILITY_NAME  ENROLLMENT  n pct  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER        63.0  .  98
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER        47.0  .  95
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START        44.0  .  95
# 3                                    SUGAR AND SPICE         NaN  .   .
# 4                         MCKINNEY CHRISTIAN ACADEMY         NaN  .   .
#
#   vac_info_type REPORTED
# 0     childcare        Y
# 1     childcare        Y
# 2     childcare        Y
# 3     childcare        N
# 4  kindergarten        N

# %%
#Clean up missing values and set to Nan
pertusis_1718.n=pertusis_1718.n.replace('.', np.nan)
pertusis_1718.pct=pertusis_1718.pct.replace('.',np.nan)

# uppercase all counties and cities
pertusis_1718.COUNTY=pertusis_1718['COUNTY'].str.upper()
pertusis_1718.CITY=pertusis_1718['CITY'].str.upper()

# %%
pertusis_1718.CITY
# Out:
# 0            ALAMEDA
# 1            ALAMEDA
# 2            ALAMEDA
# 3            ALAMEDA
# 4            ALAMEDA
# 5            ALAMEDA
# 6            ALAMEDA
# 7            ALAMEDA
# 8            ALAMEDA
# 9            ALAMEDA
# 10           ALAMEDA
# 11           ALAMEDA
# 12           ALAMEDA
# 13           ALAMEDA
# 14           ALAMEDA
# 15           ALAMEDA
# 16           ALAMEDA
# 17           ALAMEDA
# 18           ALAMEDA
# 19           ALAMEDA
# 20           ALAMEDA
# 21           ALAMEDA
# 22           ALAMEDA
# 23           ALAMEDA
# 24           ALAMEDA
# 25           ALAMEDA
# 26           ALAMEDA
# 27           ALAMEDA
# 28           ALAMEDA
# 29           ALAMEDA
#             ...
# 19279     MARYSVILLE
# 19280     MARYSVILLE
# 19281     MARYSVILLE
# 19282     MARYSVILLE
# 19283     MARYSVILLE
# 19284     MARYSVILLE
# 19285     MARYSVILLE
# 19286     MARYSVILLE
# 19287     MARYSVILLE
# 19288     MARYSVILLE
# 19289     MARYSVILLE
# 19290     OLIVEHURST
# 19291     OLIVEHURST
# 19292     OLIVEHURST
# 19293     OLIVEHURST
# 19294     OLIVEHURST
# 19295     OLIVEHURST
# 19296     OLIVEHURST
# 19297     OLIVEHURST
# 19298     OLIVEHURST
# 19299     OLIVEHURST
# 19300     OLIVEHURST
# 19301    PLUMAS LAKE
# 19302    PLUMAS LAKE
# 19303    PLUMAS LAKE
# 19304    PLUMAS LAKE
# 19305      WHEATLAND
# 19306      WHEATLAND
# 19307      WHEATLAND
# 19308      WHEATLAND
# Name: CITY, Length: 19309, dtype: object

# %%
pertusis_1718.dtypes
# Out:
# FACILITY_NUMBER         int64
# COUNTY                 object
# pub_priv_headstart     object
# CITY                   object
# FACILITY_NAME          object
# ENROLLMENT            float64
# n                      object
# pct                    object
# vac_info_type          object
# REPORTED               object
# dtype: object

# %%
# Change n and percent to floats
pertusis_1718[['n', 'pct']] = pertusis_1718[['n', 'pct']].astype('float64')

# %%
# Check conversion
pertusis_1718.dtypes
# Out:
# FACILITY_NUMBER         int64
# COUNTY                 object
# pub_priv_headstart     object
# CITY                   object
# FACILITY_NAME          object
# ENROLLMENT            float64
# n                     float64
# pct                   float64
# vac_info_type          object
# REPORTED               object
# dtype: object

# %%
pertusis_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  ALAMEDA         HEAD START  ALAMEDA
# 1         13417425  ALAMEDA         HEAD START  ALAMEDA
# 2         13420593  ALAMEDA         HEAD START  ALAMEDA
# 3         13417441  ALAMEDA            PRIVATE  ALAMEDA
# 4          6151211  ALAMEDA            PRIVATE  ALAMEDA
#
#                                        FACILITY_NAME  ENROLLMENT   n   pct  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER        63.0 NaN  98.0
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER        47.0 NaN  95.0
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START        44.0 NaN  95.0
# 3                                    SUGAR AND SPICE         NaN NaN   NaN
# 4                         MCKINNEY CHRISTIAN ACADEMY         NaN NaN   NaN
#
#   vac_info_type REPORTED
# 0     childcare        Y
# 1     childcare        Y
# 2     childcare        Y
# 3     childcare        N
# 4  kindergarten        N

# %%
sum(pertusis_1718.REPORTED=='N')
# Out:
# 1005

# %%
sum(pertusis_1718.REPORTED=='Y')
# Out:
# 18304

# %% [markdown]
# Subset dataset to those that reported

# %%
# Take subset that have numbers
vac_1718=pertusis_1718[pertusis_1718.REPORTED=='Y']

# %%
vac_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  ALAMEDA         HEAD START  ALAMEDA
# 1         13417425  ALAMEDA         HEAD START  ALAMEDA
# 2         13420593  ALAMEDA         HEAD START  ALAMEDA
# 6         13415928  ALAMEDA            PRIVATE  ALAMEDA
# 7         13419403  ALAMEDA            PRIVATE  ALAMEDA
#
#                                        FACILITY_NAME  ENROLLMENT   n   pct  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER        63.0 NaN  98.0
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER        47.0 NaN  95.0
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START        44.0 NaN  95.0
# 6                          BRIGHT HORIZONS AT GARNER       109.0 NaN  99.0
# 7                                   PETER PAN SCHOOL       100.0 NaN  99.0
#
#   vac_info_type REPORTED
# 0     childcare        Y
# 1     childcare        Y
# 2     childcare        Y
# 6     childcare        Y
# 7     childcare        Y

# %% [markdown]
# Numbers in the original document have been surpressed for <=1%, <=2%, <=5% and >=95%,>=98%,>=99% so will impute values by assuming that the percentage is equal to whatever value listed and multiply by the number of students enrolled at the school.

# %%
# Calculate n from enrollment and approximate percentage
vac_1718.loc[:,('n')]=vac_1718.n.fillna(vac_1718.ENROLLMENT*vac_1718.pct/100)
# Out:
# C:\Users\42\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
vac_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  ALAMEDA         HEAD START  ALAMEDA
# 1         13417425  ALAMEDA         HEAD START  ALAMEDA
# 2         13420593  ALAMEDA         HEAD START  ALAMEDA
# 6         13415928  ALAMEDA            PRIVATE  ALAMEDA
# 7         13419403  ALAMEDA            PRIVATE  ALAMEDA
#
#                                        FACILITY_NAME  ENROLLMENT       n  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER        63.0   61.74
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER        47.0   44.65
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START        44.0   41.80
# 6                          BRIGHT HORIZONS AT GARNER       109.0  107.91
# 7                                   PETER PAN SCHOOL       100.0   99.00
#
#     pct vac_info_type REPORTED
# 0  98.0     childcare        Y
# 1  95.0     childcare        Y
# 2  95.0     childcare        Y
# 6  99.0     childcare        Y
# 7  99.0     childcare        Y

# %%
# Change to integers 
vac_1718.loc[:,('ENROLLMENT','n','pct')]=vac_1718.loc[:,('ENROLLMENT','n','pct')].astype('int64')
# Out:
# C:\Users\42\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
vac_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  ALAMEDA         HEAD START  ALAMEDA
# 1         13417425  ALAMEDA         HEAD START  ALAMEDA
# 2         13420593  ALAMEDA         HEAD START  ALAMEDA
# 6         13415928  ALAMEDA            PRIVATE  ALAMEDA
# 7         13419403  ALAMEDA            PRIVATE  ALAMEDA
#
#                                        FACILITY_NAME  ENROLLMENT    n  pct  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER          63   61   98
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER          47   44   95
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START          44   41   95
# 6                          BRIGHT HORIZONS AT GARNER         109  107   99
# 7                                   PETER PAN SCHOOL         100   99   99
#
#   vac_info_type REPORTED
# 0     childcare        Y
# 1     childcare        Y
# 2     childcare        Y
# 6     childcare        Y
# 7     childcare        Y

# %%
# Change print settings to see all
#np.set_printoptions(threshold=np.nan)
#change back to default printing length
np.set_printoptions(threshold=5)
# Check County names
sorted(list(vac_1718.COUNTY.unique()))
# Out:
# ['ALAMEDA',
#  'AMADOR',
#  'BUTTE',
#  'CALAVERAS',
#  'COLUSA',
#  'CONTRA COSTA',
#  'DEL NORTE',
#  'EL DORADO',
#  'FRESNO',
#  'GLENN',
#  'HUMBOLDT',
#  'IMPERIAL',
#  'INYO',
#  'KERN',
#  'KINGS',
#  'LAKE',
#  'LASSEN',
#  'LOS ANGELES',
#  'MADERA',
#  'MARIN',
#  'MARIPOSA',
#  'MENDOCINO',
#  'MERCED',
#  'MODOC',
#  'MONO',
#  'MONTEREY',
#  'NAPA',
#  'NEVADA',
#  'ORANGE',
#  'PLACER',
#  'PLUMAS',
#  'RIVERSIDE',
#  'SACRAMENTO',
#  'SAN BENITO',
#  'SAN BERNARDINO',
#  'SAN DIEGO',
#  'SAN FRANCISCO',
#  'SAN JOAQUIN',
#  'SAN LUIS OBISPO',
#  'SAN MATEO',
#  'SANTA BARBARA',
#  'SANTA CLARA',
#  'SANTA CRUZ',
#  'SHASTA',
#  'SIERRA',
#  'SISKIYOU',
#  'SOLANO',
#  'SONOMA',
#  'STANISLAUS',
#  'SUTTER',
#  'TEHAMA',
#  'TRINITY',
#  'TULARE',
#  'TUOLUMNE',
#  'VENTURA',
#  'YOLO',
#  'YUBA']

# %%
#Check city names
sorted(list(vac_1718.CITY.unique()))
# Out:
# ['ACAMPO',
#  'ACTON',
#  'ACTON, CA',
#  'ADELANTO',
#  'AGOURA',
#  'AGOURA HILLS',
#  'AGUANGA',
#  'AHWAHNEE',
#  'ALAMEDA',
#  'ALAMO',
#  'ALBANY',
#  'ALHAMBRA',
#  'ALISO VIEJO',
#  'ALPAUGH',
#  'ALPINE',
#  'ALTA LOMA',
#  'ALTADENA',
#  'ALTURAS',
#  'ALVISO',
#  'AMERICAN CANYON',
#  'ANAHEIM',
#  'ANAHEIM HILLS',
#  'ANAHEIM,',
#  'ANANHEIM',
#  'ANDERSON',
#  'ANGELS CAMP',
#  'ANTELOPE',
#  'ANTIOCH',
#  'ANZA',
#  'APPLE VALLEY',
#  'APTOS',
#  'ARBOGA',
#  'ARBUCKLE',
#  'ARCADIA',
#  'ARCATA',
#  'ARLETA',
#  'ARMONA',
#  'ARNOLD',
#  'AROMAS',
#  'ARROYO GRANDE',
#  'ARTESIA',
#  'ARVIN',
#  'ATASCADERO',
#  'ATHERTON',
#  'ATWATER',
#  'AUBERRY',
#  'AUBURN',
#  'AVALON',
#  'AVENAL',
#  'AVERY',
#  'AZUSA',
#  'BAKERSFIELD',
#  'BALDWIN PARK',
#  'BALLICO',
#  'BANNING',
#  'BANTA',
#  'BARSTOW',
#  'BAY POINT',
#  'BAYSIDE',
#  'BEALE AFB',
#  'BEALE AIR FORCE BASE',
#  'BEAUMONT',
#  'BELL',
#  'BELL GARDENS',
#  'BELLA VISTA',
#  'BELLFLOWER',
#  'BELMONT',
#  'BELVEDERE',
#  'BENICA',
#  'BENICIA',
#  'BERKELEY',
#  'BERMUDA DUNES',
#  'BEVERLY HILLS',
#  'BIG BEAR CITY',
#  'BIG BEAR LAKE',
#  'BIGGS',
#  'BISHOP',
#  'BLOOMINGTON',
#  'BLUE LAKE',
#  'BLYTHE',
#  'BOLINAS',
#  'BONITA',
#  'BONSALL',
#  'BOONVILLE',
#  'BORON',
#  'BORREGO SPRINGS',
#  'BOULDER CREEK',
#  'BOULEVARD',
#  'BOYES HOT SPRINGS',
#  'BRADBURY',
#  'BRAWLEY',
#  'BREA',
#  'BRENTWOOD',
#  'BRICELAND',
#  'BRISBANE',
#  'BROWNS VALLEY',
#  'BUELLTON',
#  'BUENA PARK',
#  'BURBANK',
#  'BURLINGAME',
#  'BURNEY',
#  'BUTTONWILLOW',
#  'BYRON',
#  'CA',
#  'CABAZON',
#  'CALABASAS',
#  'CALEXICO',
#  'CALIFORNIA CITY',
#  'CALIMESA',
#  'CALIPATRIA',
#  'CALISTOGA',
#  'CALPELLA',
#  'CAMARILLO',
#  'CAMBRIA',
#  'CAMERON PARK',
#  'CAMINO',
#  'CAMPBELL',
#  'CAMPO',
#  'CANOGA PARK',
#  'CANTUA CREEK',
#  'CANYON COUNTRY',
#  'CANYON LAKE',
#  'CAPISTRANO BEACH',
#  'CAPITOLA',
#  'CARDIFF',
#  'CARDIFF BY THE SEA',
#  'CARLOTTA',
#  'CARLSBAD',
#  'CARMEL',
#  'CARMEL VALLEY',
#  'CARMICHAEL',
#  'CARPINTERIA',
#  'CARSON',
#  'CARUTHERS',
#  'CASTAIC',
#  'CASTRO VALLEY',
#  'CASTROVILLE',
#  'CATHEDRAL CITY',
#  'CATHEYS VALLEY',
#  'CAYUCOS',
#  'CERES',
#  'CERRITOS',
#  'CHALLENGE',
#  'CHATSWORTH',
#  'CHERRY VALLEY',
#  'CHESTER',
#  'CHICO',
#  'CHINO',
#  'CHINO HILLS',
#  'CHINO,',
#  'CHOWCHILLA',
#  'CHUALAR',
#  'CHULA VISTA',
#  'CHULAR',
#  'CITRUS HEIGHTS',
#  'CITY OF COMMERCE',
#  'CITY OF INDUSTRY',
#  'CLAREMONT',
#  'CLARKSBURG',
#  'CLAYTON',
#  'CLEARLAKE',
#  'CLEARLAKE OAKS',
#  'CLOVERDALE',
#  'CLOVIS',
#  'COACHELLA',
#  'COALINGA',
#  'COARSEGOLD',
#  'COLEVILLE',
#  'COLFAX',
#  'COLMA',
#  'COLTON',
#  'COLUMBIA',
#  'COLUSA',
#  'COMMERCE',
#  'COMPTON',
#  'CONCORD',
#  'COOL',
#  'COPPEROPOLIS',
#  'CORCORAN',
#  'CORNING',
#  'CORONA',
#  'CORONA DEL MAR',
#  'CORONADO',
#  'CORTE MADERA',
#  'COSTA MESA',
#  'COSTA MESA,',
#  'COTATI',
#  'COTO DE CAZA',
#  'COTTONWOOD',
#  'COURTLAND',
#  'COVELO',
#  'COVINA',
#  'CRESCENT CITY',
#  'CRESSEY',
#  'CREST PARK',
#  'CRESTLINE',
#  'CROCKETT',
#  'CUDAHAY',
#  'CUDAHY',
#  'CULVER CITY',
#  'CUPERTINO',
#  'CUTLER',
#  'CYPRESS',
#  'DALY CITY',
#  'DANA POINT',
#  'DANVILLE',
#  'DAVENPORT',
#  'DAVIS',
#  'DEL MAR',
#  'DEL REY',
#  'DEL REY OAKS',
#  'DELANO',
#  'DELHI',
#  'DENAIR',
#  'DESCANSO',
#  'DESERT HOT SPRINGS',
#  'DIAMOND BAR',
#  'DIAMOND SPRINGS',
#  'DINUBA',
#  'DISCOVERY BAY',
#  'DIXON',
#  'DORRIS',
#  'DOS PALOS',
#  'DOUGLAS CITY',
#  'DOWNEY',
#  'DUARTE',
#  'DUBLIN',
#  'DUCOR',
#  'DUNLAP',
#  'DURHAM',
#  'E. NICOLAUS',
#  'E. RANCHO DOMINGUEZ',
#  'E. WHITTIER',
#  'EARLIMART',
#  'EAST NICOLAUS',
#  'EAST PALO ALTO',
#  'EASTVALE',
#  'EDWARDS',
#  'EL CAJON',
#  'EL CENTRO',
#  'EL CERRITO',
#  'EL DORADO HILLS',
#  'EL GRANADA',
#  'EL MONTE',
#  'EL SEGUNDO',
#  'EL SEGUNDO,',
#  'EL SOBRANTE',
#  'ELK GROVE',
#  'ELVERTA',
#  'EMERALD HILLS',
#  'EMERYVILLE',
#  'EMPIRE',
#  'ENCINITAS',
#  'ENCINO',
#  'ESCALON',
#  'ESCONDIDO',
#  'ESPARTO',
#  'ETIWANDA',
#  'ETNA',
#  'EUREKA',
#  'EXETER',
#  'FAIR OAKS',
#  'FAIRFAX',
#  'FAIRFIELD',
#  'FAIRIFELD',
#  'FALL RIVER MILLS',
#  'FALLBROOK',
#  'FARMERSVILLE',
#  'FELTON',
#  'FERNDALE',
#  'FILLMORE',
#  'FIREBAUGH',
#  'FIVE POINTS',
#  'FOLSOM',
#  'FONTANA',
#  'FOOTHILL RANCH',
#  'FORESTHILL',
#  'FORESTVILLE',
#  'FORT BRAGG',
#  'FORT IRWIN',
#  'FORT JONES',
#  'FORTUNA',
#  'FOSTER CITY',
#  'FOUNTAIN VALLEY',
#  'FOWLER',
#  'FRAZIER PARK',
#  'FREEDOM',
#  'FREMONT',
#  'FREMOTN',
#  'FRENCH CAMP',
#  'FRESNO',
#  'FT. IRWIN',
#  'FULLERTON',
#  'GALT',
#  'GARDEN GROVE',
#  'GARDEN VALLEY',
#  'GARDENA',
#  'GEORGETOWN',
#  'GERBER',
#  'GEYSERVILLE',
#  'GILROY',
#  'GLEN ELLEN',
#  'GLENDALE',
#  'GLENDORA',
#  'GOLD RIVER',
#  'GOLETA',
#  'GONZALES',
#  'GRANADA HILLS',
#  'GRAND TERRACE',
#  'GRANITE BAY',
#  'GRASS VALLEY',
#  'GREENFIELD',
#  'GREENFILED',
#  'GRENADA',
#  'GRIDLEY',
#  'GROVELAND',
#  'GROVER BEACH',
#  'GUADALUPE',
#  'GUERNEVILLE',
#  'GUSTINE',
#  'HACIENDA HEIGHTS',
#  'HALF MOON BAY',
#  'HAMILTON CITY',
#  'HANFORD',
#  'HAPPY CAMP',
#  'HARBOR CITY',
#  'HAWAIIAN GARDENS',
#  'HAWTHORNE',
#  'HAYWARD',
#  'HEALDSBURG',
#  'HEBER',
#  'HELENDALE',
#  'HEMET',
#  'HERALD',
#  'HERCULES',
#  'HERMOSA BEACH',
#  'HESPERIA',
#  'HICKMAN',
#  'HIGHLAND',
#  'HIGHLAND PARK',
#  'HILLSBOROUGH',
#  'HILMAR',
#  'HOLLISTER',
#  'HOLLYWOOD',
#  'HOLTVILLE',
#  'HOOPA',
#  'HUGHSON',
#  'HUNTINGTON',
#  'HUNTINGTON BEACH',
#  'HUNTINGTON PARK',
#  'HURON',
#  'HYDESVILLE',
#  'IDYLLWILD',
#  'IMPERIAL',
#  'IMPERIAL BEACH',
#  'INDIAN WELLS',
#  'INDIO',
#  'INGLEWOOD',
#  'INYOKERN',
#  'IONE',
#  'IRVINE',
#  'ISLETON',
#  'IVANHOE',
#  'JACKSON',
#  'JAMESTOWN',
#  'JAMUAL',
#  'JAMUL',
#  'JANESVILLE',
#  'JOSHUA TREE',
#  'JULIAN',
#  'JURUPA VALLEY',
#  'KELSEYVILLE',
#  'KENSINGTON',
#  'KENTFIELD',
#  'KENWOOD',
#  'KERMAN',
#  'KERNVILLE',
#  'KETTLEMAN CITY',
#  'KEYES',
#  'KING CITY',
#  'KINGS BEACH',
#  'KINGSBURG',
#  'KNIGHTS FERRY',
#  'KNIGHTS LANDING',
#  'KNIGHTSEN',
#  'LA',
#  'LA CANADA',
#  'LA CANADA FLINTRIDGE',
#  'LA CRESCENTA',
#  'LA GRANGE',
#  'LA HABRA',
#  'LA HABRA HEIGHTS',
#  'LA JOLLA',
#  'LA MESA',
#  'LA MIRADA',
#  'LA PALMA',
#  'LA PUENTE',
#  'LA QUINTA',
#  'LA SELVA BEACH',
#  'LA VERNE',
#  'LADERA RANCH',
#  'LAFAYETTE',
#  'LAGUNA BEACH',
#  'LAGUNA HILLS',
#  'LAGUNA NIGUEL',
#  'LAGUNA WOODS',
#  'LAKE ARROWHEAD',
#  'LAKE BALBOA',
#  'LAKE ELSINORE',
#  'LAKE FOREST',
#  'LAKE HUGHES',
#  'LAKE ISABELLA',
#  'LAKE VIEW TERRACE',
#  'LAKE VIEW TERRANCE',
#  'LAKEPORT',
#  'LAKESIDE',
#  'LAKEVIEW TERRACE',
#  'LAKEWOOD',
#  'LAMONT',
#  'LANCASTER',
#  'LANCASTER,',
#  'LARKSPUR',
#  'LATHROP',
#  'LATON',
#  'LAVERNE',
#  'LAWNDALE',
#  'LAYTONVILLE',
#  'LE GRAND',
#  'LEBEC',
#  'LEMON COVE',
#  'LEMON GROVE',
#  'LEMOORE',
#  'LENNOX',
#  'LENWOOD',
#  'LEUCADIA',
#  'LINCOLN',
#  'LINDEN',
#  'LINDSAY',
#  'LITTLEROCK',
#  'LIVE OAK',
#  'LIVERMORE',
#  'LIVINGSTON',
#  'LOCKEFORD',
#  'LOCKWOOD',
#  'LODI',
#  'LOMA LINDA',
#  'LOMITA',
#  'LOMPOC',
#  'LONE PINE',
#  'LONG BEACH',
#  'LOOMIS',
#  'LOS ALAMITOS',
#  'LOS ALAMOS',
#  'LOS ALTOS',
#  'LOS ALTOS HILLS',
#  'LOS ANGELES',
#  'LOS BANOS',
#  'LOS FLORES',
#  'LOS GATOS',
#  'LOS MOLINOS',
#  'LOS NIETOS',
#  'LOS OLIVOS',
#  'LOS OSOS',
#  'LOST HILLS',
#  'LOWER LAKE',
#  'LOYALTON',
#  'LUCERNE',
#  'LUCERNE VALLEY',
#  'LYNWOOD',
#  'MADERA',
#  'MADISON',
#  'MAGALIA',
#  'MALIBU',
#  'MAMMOTH LAKES',
#  'MANHATTAN BEACH',
#  'MANTECA',
#  'MAR VISTA',
#  'MARICOPA',
#  'MARIN CITY',
#  'MARINA',
#  'MARINA DEL REY',
#  'MARIPOSA',
#  'MARTINEZ',
#  'MARYSVILLE',
#  'MATHER',
#  'MAXWELL',
#  'MAYWOOD',
#  'MC KINLEYVILLE',
#  'MCARTHUR',
#  'MCCLELLAN',
#  'MCFARLAND',
#  'MCKINLEYVILLE',
#  'MEADOW VISTA',
#  'MECCA',
#  'MENDOCINO',
#  'MENDOTA',
#  'MENIFEE',
#  'MENLO PARK',
#  'MENTONE',
#  'MERCED',
#  'MERIDIAN',
#  'MIDDLETOWN',
#  'MIDWAY CITY',
#  'MILL VALLEY',
#  'MILLBRAE',
#  'MILLVILLE',
#  'MILPITAS',
#  'MIRA LOMA',
#  'MIRANDA',
#  'MISSION HILLS',
#  'MISSION VIEJO',
#  'MODESTO',
#  'MOFFETT FIELD',
#  'MOJAVE',
#  'MONROVIA',
#  'MONTAGUE',
#  'MONTARA',
#  'MONTCLAIR',
#  'MONTEBELLO',
#  'MONTEREY',
#  'MONTEREY PARK',
#  'MONTROSE',
#  'MOORPARK',
#  'MORAGA',
#  'MORENO VALLEY',
#  'MORGAN HILL',
#  'MORONGO VALLEY',
#  'MORRO BAY',
#  'MOUNT HERMON',
#  'MOUNT SHASTA',
#  'MOUNTAIN HOUSE',
#  'MOUNTAIN VIEW',
#  'MT. SHASTA',
#  'MURPHYS',
#  'MURRIETA',
#  'MURRIETTA',
#  'N. HOLLYWOOD',
#  'N.A.S. LEMOORE',
#  'NAPA',
#  'NAS LEMOORE',
#  'NATIONAL CITY',
#  'NEEDLES',
#  'NEVADA CITY',
#  'NEW CUYAMA',
#  'NEWARK',
#  'NEWBERRY SPRINGS',
#  'NEWBURY PARK',
#  'NEWCASTLE',
#  'NEWHALL',
#  'NEWMAN',
#  'NEWPORT BEACH',
#  'NEWPORT BEACH,',
#  'NIPOMO',
#  'NORCO',
#  'NORTH FORK',
#  'NORTH HIGHLANDS',
#  'NORTH HILLS',
#  'NORTH HOLLYWOOD',
#  'NORTH SHORE',
#  'NORTH TUSTIN',
#  'NORTHRIDGE',
#  'NORWALK',
#  'NOVATO',
#  'NUEVO',
#  "O'NEALS",
#  'OAK HILLS',
#  'OAK PARK',
#  'OAK VIEW',
#  'OAKDALE',
#  'OAKHURST',
#  'OAKLAND',
#  'OAKLEY',
#  'OCCIDENTAL',
#  'OCEANO',
#  'OCEANSIDE',
#  'OJAI',
#  'OLIVEHURST',
#  'OLYMPIC VALLEY',
#  'ONTARIO',
#  'ORANGE',
#  'ORANGE COVE',
#  'ORANGEVALE',
#  'ORCUTT',
#  'ORINDA',
#  'ORLAND',
#  'ORO GRANDE',
#  'OROSI',
#  'OROVILLE',
#  'OXNARD',
#  'PACIFIC GROVE',
#  'PACIFIC PALISADES',
#  'PACIFICA',
#  'PACOIMA',
#  'PACOMIA',
#  'PALERMO',
#  'PALM DESERT',
#  'PALM SPRINGS',
#  'PALMDALE',
#  'PALO ALTO',
#  'PALO CEDRO',
#  'PALOS VERDES',
#  'PALOS VERDES ESTATES',
#  'PALOS VERDES PENINSULA',
#  'PANORAM CITY',
#  'PANORAMA CITY',
#  'PARADISE',
#  'PARAMOUNT',
#  'PARLIER',
#  'PASADENA',
#  'PASO ROBLES',
#  'PATTERSON',
#  'PAUMA VALLEY',
#  'PEARBLOSSOM',
#  'PENN VALLEY',
#  'PENNGROVE',
#  'PENRYN',
#  'PERRIS',
#  'PESCADERO',
#  'PETALUMA',
#  'PETROLIA',
#  'PHELAN',
#  'PICO RIVERA',
#  'PIEDMONT',
#  'PINE VALLEY',
#  'PINEDALE',
#  'PINOLE',
#  'PINON HILLS',
#  'PIONEER',
#  'PIRU',
#  'PISMO BEACH',
#  'PITTSBURG',
#  'PIXLEY',
#  'PLACENTIA',
#  'PLACERVILLE',
#  'PLANADA',
#  'PLAYA DEL REY',
#  'PLAYA VISTA',
#  'PLEASANT GROVE',
#  'PLEASANT HILL',
#  'PLEASANTON',
#  'PLUMAS LAKE',
#  'PLYMOUTH',
#  'POINT ARENA',
#  'POINT REYES STATION',
#  'POLLOCK PINES',
#  'POMONA',
#  'PORT HUENEME',
#  'PORTER RANCH',
#  'PORTERVILLE',
#  'PORTOLA',
#  'PORTOLA VALLEY',
#  'POTRERO',
#  'POTTER VALLEY',
#  'POWAY',
#  'PRATHER',
#  'PRUNEDALE',
#  'PT. REYES STATION',
#  'QUAIL VALLEY',
#  'QUARTZ HILL',
#  'QUINCY',
#  'RAINBOW',
#  'RAISIN CITY',
#  'RAMONA',
#  'RANCHO CORDOVA',
#  'RANCHO CUCAMONGA',
#  'RANCHO DOMINGUEZ',
#  'RANCHO MIRAGE',
#  'RANCHO MURIETA',
#  'RANCHO PALOS VERDES',
#  'RANCHO SAN MARGARITA',
#  'RANCHO SANTA FE',
#  'RANCHO SANTA MARGARI',
#  'RANCHO SANTA MARGARITA',
#  'RANCHO STA MARGAITA',
#  'RANCHO STA MARGARITA',
#  'RANCHOS PALOS VERDES',
#  'RCHO STA MARG',
#  'RED BLUFF',
#  'REDDING',
#  'REDLANDS',
#  'REDONDO BEACH',
#  'REDWAY',
#  'REDWOOD CITY',
#  'REDWOOD VALLEY',
#  'REEDLEY',
#  'RESCUE',
#  'RESEDA',
#  'RIALTO',
#  'RICHGROVE',
#  'RICHMOND',
#  'RIDGECREST',
#  'RIM FOREST',
#  'RIO DELL',
#  'RIO LINDA',
#  'RIO VISTA',
#  'RIPON',
#  'RIVERBANK',
#  'RIVERDALE',
#  'RIVERSIDE',
#  'RIVERSIDE,',
#  'ROCKLIN',
#  'RODEO',
#  'ROHNERT PARK',
#  'ROLLING HILLS ESTATE',
#  'ROLLING HILLS ESTATES',
#  'ROMOLAND',
#  'ROSAMOND',
#  'ROSEMEAD',
#  'ROSEVILLE',
#  'ROSS',
#  'ROSSMOOR',
#  'ROWLAND HEIGHTS',
#  'ROYAL OAKS',
#  'RUNNING SPRINGS',
#  'RUTHERFORD',
#  'S. EL MONTE',
#  'S. LAKE TAHOE',
#  'SACRAMENTO',
#  'SALIDA',
#  'SALINAS',
#  'SALTON CITY',
#  'SAN ANDREAS',
#  'SAN ANSELMO',
#  'SAN BERARDINO',
#  'SAN BERNARDINO',
#  'SAN BRUNO',
#  'SAN CARLOS',
#  'SAN CLEMENTE',
#  'SAN DIEGO',
#  'SAN DIMAS',
#  'SAN FERNANDO',
#  'SAN FRANCISCO',
#  'SAN FRNCISCO',
#  'SAN GABRIEL',
#  'SAN GERONIMO',
#  'SAN JACINTO',
#  'SAN JOAQUIN',
#  'SAN JOSE',
#  'SAN JOSE,',
#  'SAN JUAN BAUTISTA',
#  'SAN JUAN CAPISTRANO',
#  'SAN LEANDRO',
#  'SAN LORENZO',
#  'SAN LUIS OBISPO',
#  'SAN MARCOS',
#  'SAN MARINO',
#  'SAN MARTIN',
#  'SAN MATEO',
#  'SAN MIGUEL',
#  'SAN PABLO',
#  'SAN PEDRO',
#  'SAN RAFAEL',
#  'SAN RAMON',
#  'SAN YSIDRO',
#  'SANGER',
#  'SANTA ANA',
#  'SANTA BARARA',
#  'SANTA BARBARA',
#  'SANTA CATALINA',
#  'SANTA CLARA',
#  'SANTA CLARITA',
#  'SANTA CRUZ',
#  'SANTA FE SPRINGS',
#  'SANTA MARGARITA',
#  'SANTA MARIA',
#  'SANTA MONICA',
#  'SANTA NELLA',
#  'SANTA PAULA',
#  'SANTA ROSA',
#  'SANTA YNEZ',
#  'SANTEE',
#  'SARATOGA',
#  'SAUGUS',
#  'SAUSALITO',
#  'SCOTTS VALLEY',
#  'SEAL BEACH',
#  'SEASIDE',
#  'SEBASTOPOL',
#  'SEELEY',
#  'SELMA',
#  'SEPULVEDA',
#  'SHAFTER',
#  'SHANDON',
#  'SHASTA',
#  'SHASTA LAKE',
#  'SHASTA LAKE CITY',
#  'SHERMAN OAKS',
#  'SHINGLE SPRINGS',
#  'SHINGLETOWN',
#  'SIERRA MADRE',
#  'SIGNAL HILL',
#  'SILVERADO',
#  'SILVERADO CANYON',
#  'SIMI VALLEY',
#  'SLOUGHHOUSE',
#  'SMITH RIVER',
#  'SOLANA BEACH',
#  'SOLEDAD',
#  'SOLVANG',
#  'SOMERSET',
#  'SOMIS',
#  'SONOMA',
#  'SONORA',
#  'SOQUEL',
#  'SOULSBYVILLE',
#  'SOUTH EL MONTE',
#  'SOUTH GATE',
#  'SOUTH LAKE TAHOE',
#  'SOUTH LATE TAHOE',
#  'SOUTH PASADENA',
#  'SOUTH SAN FRANCISCO',
#  'SOUTH SAN GABRIEL',
#  'SOUTH WHITTIER',
#  'SPRECKELS',
#  'SPRECKLES',
#  'SPRING VALLEY',
#  'SPRINGVILLE',
#  'ST. HELENA',
#  'STANFORD',
#  'STANTON',
#  'STEVENSON RANCH',
#  'STEVENSONS RANCH',
#  'STEVINSON',
#  'STOCKTON',
#  'STRATFORD',
#  'STRATHMORE',
#  'STUDIO CITY',
#  'SUISUN',
#  'SUISUN CITY',
#  'SUN CITY',
#  'SUN VALLEY',
#  'SUNLAND',
#  'SUNNYALE',
#  'SUNNYVALE',
#  'SUNOL',
#  'SUNSET BEACH',
#  'SUPELVEDA',
#  'SUSANVILLE',
#  'SUTTER',
#  'SUTTER CREEK',
#  'SYLMAR',
#  'TAFT',
#  'TAHOE CITY',
#  'TARZANA',
#  'TEHACHAPI',
#  'TEHAMA',
#  'TEMECULA',
#  'TEMPLE CITY',
#  'TEMPLETON',
#  'TERRA BELLA',
#  'THERMAL',
#  'THORNTON',
#  'THOUSAND OAKS',
#  'THOUSAND PALMS',
#  'THREE RIVERS',
#  'TIBURON',
#  'TIPTON',
#  'TOLLHOUSE',
#  'TOMALES',
#  'TOPANGA',
#  'TORRANCE',
#  'TRABUCO CANYON',
#  'TRACY',
#  'TRANQUILLITY',
#  'TRAVER',
#  'TRAVIS AFB',
#  'TRINIDAD',
#  'TRONA',
#  'TRUCKEE',
#  'TUJUNGA',
#  'TULARE',
#  'TULELAKE',
#  'TUOLUMNE',
#  'TUPMAN',
#  'TURLOCK',
#  'TURLOCK,',
#  'TUSTIN',
#  'TWAIN HARTE',
#  'TWENTY NINE PALMS',
#  'TWENTYNINE PALMS',
#  'TWIN PEAKS',
#  'UKIAH',
#  'UNION CITY',
#  'UPLAND',
#  'UPPER LAKE',
#  'UPPERLAKE',
#  'VACAVILLE',
#  'VALENCIA',
#  'VALINDA',
#  'VALLEJO',
#  'VALLEY CENTER',
#  'VALLEY GLEN',
#  'VALLEY SPRINGS',
#  'VALLEY VILLAGE',
#  'VAN NUYS',
#  'VANDENBERG AFB',
#  'VANDENBERG AIR FORCE BASE',
#  'VENICE',
#  'VENTURA',
#  'VICTOR',
#  'VICTORVILLE',
#  'VILLA PARK',
#  'VISALIA',
#  'VISTA',
#  'W. SACRAMENTO',
#  'WALNUT',
#  'WALNUT CREEK',
#  'WALNUT CREET',
#  'WALNUT GROVE',
#  'WALNUT PARK',
#  'WALNUT VALLEY',
#  'WARNER SPRINGS',
#  'WASCO',
#  'WATERFORD',
#  'WATSONVILLE',
#  'WEAVERVILLE',
#  'WEED',
#  'WEIMAR',
#  'WELDON',
#  'WEST COVINA',
#  'WEST HILLS',
#  'WEST HOLLYWOOD',
#  'WEST SACRAMENTO',
#  'WESTCHESTER',
#  'WESTLAKE VILLAGE',
#  'WESTLEY',
#  'WESTMINISTER',
#  'WESTMINSTER',
#  'WESTMORLAND',
#  'WHEATLAND',
#  'WHITMORE',
#  'WHITTIER',
#  'WILDOMAR',
#  'WILLIAMS',
#  'WILLITS',
#  'WILLOW CREEK',
#  'WILLOWS',
#  'WILMINGTON',
#  'WILTON',
#  'WINCHESTER',
#  'WINDSOR',
#  'WINNETKA',
#  'WINTERHAVEN',
#  'WINTERS',
#  'WINTON',
#  'WOODLAKE',
#  'WOODLAND',
#  'WOODLAND HILLS',
#  'WOODSIDE',
#  'WRIGHTWOOD',
#  'YERMO',
#  'YORBA LINDA',
#  'YOUNTVILLE',
#  'YREKA',
#  'YUBA CITY',
#  'YUCAIPA',
#  'YUCCA VALLEY']

# %%
# Fix City Typos
vac_1718.loc[vac_1718.CITY=='ACTON, CA', 'CITY']='ACTON'
vac_1718.loc[vac_1718.CITY=='AGOURA', 'CITY']='AGOURA HILLS'
vac_1718.loc[vac_1718.CITY=='ANAHEIM,', 'CITY']='ANAHEIM'
vac_1718.loc[vac_1718.CITY=='ANANHEIM,', 'CITY']='ANAHEIM'
vac_1718.loc[vac_1718.CITY=='CA', 'CITY']='NAPA'
vac_1718.loc[vac_1718.CITY=='BEALE AIR FORCE BASE', 'CITY']='BEALE AFB' # to match census name
vac_1718.loc[vac_1718.CITY=='BENICA', 'CITY']='BENICIA'
vac_1718.loc[vac_1718.CITY=='CARDIFF', 'CITY']='CARDIFF BY THE SEA'
vac_1718.loc[vac_1718.CITY=='CARMEL', 'CITY']='CARMEL VALLEY'
vac_1718.loc[vac_1718.CITY=='CHINO,', 'CITY']='CHINO'
vac_1718.loc[vac_1718.CITY=='CHULAR', 'CITY']='CHUALAR'
vac_1718.loc[vac_1718.CITY=='CITY OF COMMERCE', 'CITY']='COMMERCE'
vac_1718.loc[vac_1718.CITY=='CITY OF INDUSTRY', 'CITY']='INDUSTRY'
vac_1718.loc[vac_1718.CITY=='CUDAHAY', 'CITY']='CUDAHY'
vac_1718.loc[vac_1718.CITY=='E. NICOLAUS', 'CITY']='EAST NICOLAUS'
vac_1718.loc[vac_1718.CITY=='E. RANCHO DOMINGUEZ', 'CITY']='EAST RANCHO DOMINGUEZ'
vac_1718.loc[vac_1718.CITY=='E. WHITTIER', 'CITY']='EAST WHITTIER'
vac_1718.loc[vac_1718.CITY=='EL SEGUNDO,', 'CITY']='EL SEGUNDO'
vac_1718.loc[vac_1718.CITY=='FAIRIFELD', 'CITY']='FAIRFIELD'
vac_1718.loc[vac_1718.CITY=='FREMOTN', 'CITY']='FREMONT'
vac_1718.loc[vac_1718.CITY=='FT. IRWIN', 'CITY']='FORT IRWIN'
vac_1718.loc[vac_1718.CITY=='GREENFILED', 'CITY']='GREENFIELD'
vac_1718.loc[vac_1718.CITY=='HUNTINGTON', 'CITY']='HUNTINGTON PARK'
vac_1718.loc[vac_1718.CITY=='JAMUAL', 'CITY']='JAMUL'
vac_1718.loc[vac_1718.CITY=='LA', 'CITY']='LOS ANGELES'
vac_1718.loc[vac_1718.CITY=='LA CANADA', 'CITY']='LA CANADA FLINTRIDGE'
vac_1718.loc[vac_1718.CITY=='LAKE VIEW TERRANCE', 'CITY']='LAKE VIEW TERRACE'
vac_1718.loc[vac_1718.CITY=='LAKEVIEW TERRACE', 'CITY']='LAKE VIEW TERRACE'
vac_1718.loc[vac_1718.CITY=='LANCASTER,', 'CITY']='LANCASTER'
vac_1718.loc[vac_1718.CITY=='LAVERNE', 'CITY']='LA VERNE'
vac_1718.loc[vac_1718.CITY=='MC KINLEYVILLE', 'CITY']='MCKINLEYVILLE'
vac_1718.loc[vac_1718.CITY=='MONTROSE', 'CITY']='LA CRESCENTA-MONTROSE'
vac_1718.loc[vac_1718.CITY=='MT. SHASTA', 'CITY']='MOUNT SHASTA'
vac_1718.loc[vac_1718.CITY=='N. HOLLYWOOD', 'CITY']='NORTH HOLLYWOOD'
vac_1718.loc[vac_1718.CITY=='N.A.S. LEMOORE', 'CITY']='LEMOORE STATION' # match census
vac_1718.loc[vac_1718.CITY=='NAS LEMOORE', 'CITY']='LEMOORE STATION'
vac_1718.loc[vac_1718.CITY=='NEWPORT BEACH,', 'CITY']='NEWPORT BEACH'
vac_1718.loc[vac_1718.CITY=='PACOMIA', 'CITY']='PACOIMA'
vac_1718.loc[vac_1718.CITY=='PANORAM ', 'CITY']='PANORAMA CITY'
vac_1718.loc[vac_1718.CITY=='PT. REYES STATION', 'CITY']='POINT REYES STATION'
vac_1718.loc[vac_1718.CITY=='RANCHO SANTA MARGARI', 'CITY']='RANCHO SANTA MARGARITA'
vac_1718.loc[vac_1718.CITY=='RANCHO SAN MARGARITA', 'CITY']='RANCHO SANTA MARGARITA'
vac_1718.loc[vac_1718.CITY=='RANCHO STA MARGAITA', 'CITY']='RANCHO SANTA MARGARITA'
vac_1718.loc[vac_1718.CITY=='RANCHO STA MARGARITA', 'CITY']='RANCHO SANTA MARGARITA'
vac_1718.loc[vac_1718.CITY=='RCHO STA MARG', 'CITY']='RANCHO SANTA MARGARITA'
vac_1718.loc[vac_1718.CITY=='RANCHOS PALOS VERDES', 'CITY']='RANCHO PALOS VERDES'
vac_1718.loc[vac_1718.CITY=='RIVERSIDE,', 'CITY']='RIVERSIDE'
vac_1718.loc[vac_1718.CITY=='ROLLING HILLS ESTATE', 'CITY']='ROLLING HILLS ESTATES'
vac_1718.loc[vac_1718.CITY=='S. EL MONTE', 'CITY']='SOUTH EL MONTE'
vac_1718.loc[vac_1718.CITY=='S. LAKE TAHOE', 'CITY']='SOUTH LAKE TAHOE'
vac_1718.loc[vac_1718.CITY=='SAN BERARDINO', 'CITY']='SAN BERNARDINO'
vac_1718.loc[vac_1718.CITY=='SAN FRNCISCO', 'CITY']='SAN FRANCISCO'
vac_1718.loc[vac_1718.CITY=='SAN JOSE,', 'CITY']='SAN JOSE'
vac_1718.loc[vac_1718.CITY=='SANTA BARARA', 'CITY']='SANTA BARBARA'
vac_1718.loc[vac_1718.CITY=='SHASTA LAKE CITY', 'CITY']='SHASTA LAKE'
vac_1718.loc[vac_1718.CITY=='SILVERADO CANYON', 'CITY']='SILVERADO'
vac_1718.loc[vac_1718.CITY=='SOUTH LATE TAHOE', 'CITY']='SOUTH LAKE TAHOE'
vac_1718.loc[vac_1718.CITY=='SPRECKLES', 'CITY']='SPRECKELS'
vac_1718.loc[vac_1718.CITY=='STEVENSONS RANCH', 'CITY']='STEVENSON RANCH'
vac_1718.loc[vac_1718.CITY=='SUISUN', 'CITY']='SUISUN CITY'
vac_1718.loc[vac_1718.CITY=='SUNNYALE', 'CITY']='SUNNYVALE'
vac_1718.loc[vac_1718.CITY=='SUPELVEDA', 'CITY']='SEPULVEDA'
vac_1718.loc[vac_1718.CITY=='TURLOCK,', 'CITY']='TURLOCK'
vac_1718.loc[vac_1718.CITY=='UPPERLAKE', 'CITY']='UPPER LAKE'
vac_1718.loc[vac_1718.CITY=='VANDENBERG AIR FORCE BASE', 'CITY']='VANDENBERG AFB' # match census
vac_1718.loc[vac_1718.CITY=='W. SACRAMENTO', 'CITY']='WEST SACRAMENTO'
# Out:
# C:\Users\42\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Change case to title case
vac_1718.COUNTY=vac_1718['COUNTY'].str.title()
vac_1718.CITY=vac_1718['CITY'].str.title()
# Out:
# C:\Users\42\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#Get count of students vaccinated by county,city and grade
vac_n=vac_1718.groupby(by=['COUNTY','CITY','vac_info_type'], as_index=False)['n'].sum()
vac_n
# Out:
#        COUNTY             CITY vac_info_type     n
# 0     Alameda          Alameda     7th grade   931
# 1     Alameda          Alameda     childcare  1231
# 2     Alameda          Alameda  kindergarten   986
# 3     Alameda           Albany     7th grade   255
# 4     Alameda           Albany     childcare   249
# 5     Alameda           Albany  kindergarten   307
# 6     Alameda         Berkeley     7th grade   908
# 7     Alameda         Berkeley     childcare  2346
# 8     Alameda         Berkeley  kindergarten   860
# 9     Alameda    Castro Valley     7th grade   776
# 10    Alameda    Castro Valley     childcare   797
# 11    Alameda    Castro Valley  kindergarten   864
# 12    Alameda           Dublin     7th grade   939
# 13    Alameda           Dublin     childcare  1275
# 14    Alameda           Dublin  kindergarten  1150
# 15    Alameda       Emeryville     7th grade    50
# 16    Alameda       Emeryville     childcare   238
# 17    Alameda       Emeryville  kindergarten    70
# 18    Alameda          Fremont     7th grade  2855
# 19    Alameda          Fremont     childcare  4388
# 20    Alameda          Fremont  kindergarten  3743
# 21    Alameda          Hayward     7th grade  1803
# 22    Alameda          Hayward     childcare  1852
# 23    Alameda          Hayward  kindergarten  2101
# 24    Alameda        Livermore     7th grade  1047
# 25    Alameda        Livermore     childcare  1439
# 26    Alameda        Livermore  kindergarten  1331
# 27    Alameda           Newark     7th grade   514
# 28    Alameda           Newark     childcare  1015
# 29    Alameda           Newark  kindergarten   673
# ...       ...              ...           ...   ...
# 2304     Yolo          Esparto     childcare    41
# 2305     Yolo          Esparto  kindergarten    60
# 2306     Yolo  Knights Landing  kindergarten    57
# 2307     Yolo          Madison     childcare    39
# 2308     Yolo  West Sacramento     7th grade   655
# 2309     Yolo  West Sacramento     childcare   415
# 2310     Yolo  West Sacramento  kindergarten   817
# 2311     Yolo          Winters     7th grade   133
# 2312     Yolo          Winters     childcare   176
# 2313     Yolo          Winters  kindergarten   127
# 2314     Yolo         Woodland     7th grade   799
# 2315     Yolo         Woodland     childcare   928
# 2316     Yolo         Woodland  kindergarten   867
# 2317     Yuba           Arboga     childcare    61
# 2318     Yuba        Beale Afb     childcare    62
# 2319     Yuba        Beale Afb  kindergarten   124
# 2320     Yuba    Browns Valley  kindergarten    22
# 2321     Yuba        Challenge  kindergarten    23
# 2322     Yuba       Marysville     7th grade   409
# 2323     Yuba       Marysville     childcare   352
# 2324     Yuba       Marysville  kindergarten   402
# 2325     Yuba       Olivehurst     7th grade   406
# 2326     Yuba       Olivehurst     childcare   221
# 2327     Yuba       Olivehurst  kindergarten   404
# 2328     Yuba      Plumas Lake     7th grade   150
# 2329     Yuba      Plumas Lake     childcare    53
# 2330     Yuba      Plumas Lake  kindergarten   177
# 2331     Yuba        Wheatland     7th grade   139
# 2332     Yuba        Wheatland     childcare    99
# 2333     Yuba        Wheatland  kindergarten    90
#
# [2334 rows x 4 columns]

# %%
#Export count of students vaccinated by county,city and grade
vac_n.to_csv("vac_n_table1718.CSV")

# %%
#Get average percentage of students vaccinated by county,city and grade
vac_pct=vac_1718.groupby(by=['COUNTY','CITY','vac_info_type'], as_index=False)['pct'].mean()
vac_pct
# Out:
#        COUNTY             CITY vac_info_type        pct
# 0     Alameda          Alameda     7th grade  94.900000
# 1     Alameda          Alameda     childcare  96.000000
# 2     Alameda          Alameda  kindergarten  96.384615
# 3     Alameda           Albany     7th grade  98.000000
# 4     Alameda           Albany     childcare  95.571429
# 5     Alameda           Albany  kindergarten  97.666667
# 6     Alameda         Berkeley     7th grade  96.750000
# 7     Alameda         Berkeley     childcare  92.750000
# 8     Alameda         Berkeley  kindergarten  91.333333
# 9     Alameda    Castro Valley     7th grade  97.000000
# 10    Alameda    Castro Valley     childcare  89.384615
# 11    Alameda    Castro Valley  kindergarten  97.416667
# 12    Alameda           Dublin     7th grade  97.200000
# 13    Alameda           Dublin     childcare  92.857143
# 14    Alameda           Dublin  kindergarten  97.800000
# 15    Alameda       Emeryville     7th grade  96.000000
# 16    Alameda       Emeryville     childcare  96.000000
# 17    Alameda       Emeryville  kindergarten  98.000000
# 18    Alameda          Fremont     7th grade  96.000000
# 19    Alameda          Fremont     childcare  96.196970
# 20    Alameda          Fremont  kindergarten  97.538462
# 21    Alameda          Hayward     7th grade  97.272727
# 22    Alameda          Hayward     childcare  95.742857
# 23    Alameda          Hayward  kindergarten  97.214286
# 24    Alameda        Livermore     7th grade  96.125000
# 25    Alameda        Livermore     childcare  96.416667
# 26    Alameda        Livermore  kindergarten  96.928571
# 27    Alameda           Newark     7th grade  97.333333
# 28    Alameda           Newark     childcare  96.611111
# 29    Alameda           Newark  kindergarten  96.800000
# ...       ...              ...           ...        ...
# 2304     Yolo          Esparto     childcare  95.000000
# 2305     Yolo          Esparto  kindergarten  97.000000
# 2306     Yolo  Knights Landing  kindergarten  97.000000
# 2307     Yolo          Madison     childcare  95.000000
# 2308     Yolo  West Sacramento     7th grade  96.444444
# 2309     Yolo  West Sacramento     childcare  96.142857
# 2310     Yolo  West Sacramento  kindergarten  87.666667
# 2311     Yolo          Winters     7th grade  99.000000
# 2312     Yolo          Winters     childcare  95.750000
# 2313     Yolo          Winters  kindergarten  99.000000
# 2314     Yolo         Woodland     7th grade  97.666667
# 2315     Yolo         Woodland     childcare  95.904762
# 2316     Yolo         Woodland  kindergarten  97.454545
# 2317     Yuba           Arboga     childcare  97.000000
# 2318     Yuba        Beale Afb     childcare  98.000000
# 2319     Yuba        Beale Afb  kindergarten  97.000000
# 2320     Yuba    Browns Valley  kindergarten  95.000000
# 2321     Yuba        Challenge  kindergarten  92.000000
# 2322     Yuba       Marysville     7th grade  92.000000
# 2323     Yuba       Marysville     childcare  94.571429
# 2324     Yuba       Marysville  kindergarten  86.200000
# 2325     Yuba       Olivehurst     7th grade  97.000000
# 2326     Yuba       Olivehurst     childcare  94.000000
# 2327     Yuba       Olivehurst  kindergarten  92.600000
# 2328     Yuba      Plumas Lake     7th grade  99.000000
# 2329     Yuba      Plumas Lake     childcare  95.000000
# 2330     Yuba      Plumas Lake  kindergarten  98.000000
# 2331     Yuba        Wheatland     7th grade  99.000000
# 2332     Yuba        Wheatland     childcare  96.500000
# 2333     Yuba        Wheatland  kindergarten  98.000000
#
# [2334 rows x 4 columns]

# %%
#Export average percentage of students vaccinated by county,city and grade
vac_pct.to_csv("vac_pct_table1718.CSV")

# %%
vac_1718.head()
# Out:
#    FACILITY_NUMBER   COUNTY pub_priv_headstart     CITY  \
# 0         10214883  Alameda         HEAD START  Alameda
# 1         13417425  Alameda         HEAD START  Alameda
# 2         13420593  Alameda         HEAD START  Alameda
# 6         13415928  Alameda            PRIVATE  Alameda
# 7         13419403  Alameda            PRIVATE  Alameda
#
#                                        FACILITY_NAME  ENROLLMENT    n  pct  \
# 0         ALAMEDA HEAD START . ANGELA AGUILAR CENTER          63   61   98
# 1           ALAMEDA HEAD START . SUE MATHESON CENTER          47   44   95
# 2  ALAMEDA HEAD START. COLLEGE OF ALAMEDA HEAD START          44   41   95
# 6                          BRIGHT HORIZONS AT GARNER         109  107   99
# 7                                   PETER PAN SCHOOL         100   99   99
#
#   vac_info_type REPORTED
# 0     childcare        Y
# 1     childcare        Y
# 2     childcare        Y
# 6     childcare        Y
# 7     childcare        Y

# %%
#Export full cleaned data
vac_1718.to_csv("clean1718.csv", index=False)

# %% [markdown]
# ## Census Data Cleaning

# %% [markdown]
# ### Demographics

# %%
# Import and clean census data for basic demographics age gender race
census16 = pd.read_csv("Raw_Data/Census/ACS_16_demographic.csv",encoding = "ISO-8859-1",header=[0],na_values=['-'],)

# %%
census16.head()

# %%
demographic16 = census16[['GEO.id','GEO.id2','GEO.display-label',
                     'HC01_VC03',
                     'HC01_VC04','HC03_VC04',
                     'HC01_VC05','HC03_VC05',
                     'HC01_VC08','HC03_VC08',
                     'HC01_VC09','HC03_VC09',
                     'HC01_VC10','HC03_VC10',
                     'HC01_VC11','HC03_VC11',
                     'HC01_VC12','HC03_VC12',
                     'HC01_VC13','HC03_VC13',
                     'HC01_VC14','HC03_VC14',
                     'HC01_VC15','HC03_VC15',
                     'HC01_VC16','HC03_VC16',
                     'HC01_VC17','HC03_VC17',
                     'HC01_VC18','HC03_VC18',
                     'HC01_VC19','HC03_VC19',
                     'HC01_VC20','HC03_VC20',
                     'HC01_VC23','HC03_VC23',
                     'HC01_VC88','HC03_VC88',
                     'HC01_VC94','HC03_VC94',
                     'HC01_VC95','HC03_VC95',
                     'HC01_VC96','HC03_VC96',
                     'HC01_VC97','HC03_VC97',
                     'HC01_VC98','HC03_VC98',
                     'HC01_VC99','HC03_VC99',
                     'HC01_VC100','HC03_VC100',
                     'HC01_VC101','HC03_VC101',
                     'HC01_VC102','HC03_VC102'                 
        ]]

# %%
demographic16.dtypes

# %%
# demographic16[['HC01_VC03','HC01_VC04','HC01_VC05','HC01_VC08','HC01_VC09','HC01_VC10','HC01_VC11','HC01_VC12','HC01_VC13',
#           'HC01_VC14','HC01_VC15','HC01_VC16','HC01_VC17','HC01_VC18','HC01_VC19','HC01_VC20','HC01_VC23','HC01_VC88',
#           'HC01_VC94','HC01_VC95','HC01_VC96','HC01_VC97','HC01_VC98',
#           'HC01_VC99','HC01_VC100','HC01_VC101','HC01_VC102']] = demographic16[['HC01_VC03','HC01_VC04','HC01_VC05','HC01_VC08','HC01_VC09','HC01_VC10','HC01_VC11','HC01_VC12','HC01_VC13',
#           'HC01_VC14','HC01_VC15','HC01_VC16','HC01_VC17','HC01_VC18','HC01_VC19','HC01_VC20','HC01_VC23','HC01_VC88',
#           'HC01_VC94','HC01_VC95','HC01_VC96','HC01_VC97','HC01_VC98',
#           'HC01_VC99','HC01_VC100','HC01_VC101','HC01_VC102']].astype('float64')

# %%
#combine other race, two or more races (HC01_VC99, HC01_VC100, HC01_VC101, HC01_VC102)
demographic16['other']=pd.Series(census16['HC01_VC99']+census16['HC01_VC100']+census16['HC01_VC101']+census16['HC01_VC102'])

# %%
demographic16['other_pct']=pd.Series(census16['HC03_VC99']+census16['HC03_VC100']+census16['HC03_VC101']+census16['HC03_VC102'])

# %%
demographic16.rename(columns={'GEO.display-label': 'city',
                         'HC01_VC03': 'tot_pop', 
                         'HC01_VC04': 'male',
                         'HC01_VC05': 'female',
                         'HC01_VC08':'under_5',
                         'HC01_VC09':'5_9',
                         'HC01_VC10':'10_14',
                         'HC01_VC11':'15_19',
                         'HC01_VC12':'20_24',
                         'HC01_VC13':'25_34',
                         'HC01_VC14':'35_44',
                         'HC01_VC15':'45_54',
                         'HC01_VC16':'55_59',
                         'HC01_VC17':'60_64',
                         'HC01_VC18':'65_74',
                         'HC01_VC19':'75_84',
                         'HC01_VC20':'85_over',
                         'HC01_VC23':'median_age',
                         'HC01_VC88':'hispanic_latino',
                         'HC01_VC89':'mexican',
                         'HC01_VC94':'white',
                         'HC01_VC95':'black',
                         'HC01_VC96':'aian',
                         'HC01_VC97':'asian',
                         'HC01_VC98':'nhopi',

                         'HC03_VC04': 'male_pct',
                         'HC03_VC05': 'female_pct',
                         'HC03_VC08':'under_5_pct',
                         'HC03_VC09':'5_9_pct',
                         'HC03_VC10':'10_14_pct',
                         'HC03_VC11':'15_19_pct',
                         'HC03_VC12':'20_24_pct',
                         'HC03_VC13':'25_34_pct',
                         'HC03_VC14':'35_44_pct',
                         'HC03_VC15':'45_54_pct',
                         'HC03_VC16':'55_59_pct',
                         'HC03_VC17':'60_64_pct',
                         'HC03_VC18':'65_74_pct',
                         'HC03_VC19':'75_84_pct',
                         'HC03_VC20':'85_over_pct',
                         'HC03_VC23':'median_age_pct',
                         'HC03_VC88':'hispanic_latino_pct',
                         'HC03_VC89':'mexican_pct',
                         'HC03_VC94':'white_pct',
                         'HC03_VC95':'black_pct',
                         'HC03_VC96':'aian_pct',
                         'HC03_VC97':'asian_pct',
                         'HC03_VC98':'nhopi_pct'
                        }, 
                inplace=True)
# Other race categories
#                          'HC01_VC99':'other_only',
#                          'HC01_VC100':'more_two_races',
#                          'HC01_VC101':'more_two_races_other',
#                          'HC01_VC102':'more_two_races_other_exclude',

# %%
demographic16.dtypes

# %%
demographic16['city']=demographic16.city.replace(' city, California', '', regex=True)

# %%
demographic16['city']=demographic16.city.replace(' CDP, California', '', regex=True)

# %%
demographic16['city']=demographic16.city.replace(' town, California', '', regex=True)

# %%
## Uppercase cities
demographic16['city']=demographic16['city'].str.upper()

# %%
demographic16=demographic16.drop(columns=['HC01_VC99','HC03_VC99','HC01_VC100','HC03_VC100','HC01_VC101','HC03_VC101','HC01_VC102','HC03_VC102'])
demographic16

# %% [markdown]
# ### Median Household Income and Health insurance Status

# %% [markdown]
# Median Household Income has categories 2,500-, 250,000+ which was changed to 2500 and 250000.

# %%
# Import and clean acs data for income and insurance status
acs16 = pd.read_csv("Raw_Data/Census/ACS_16_economic.csv", encoding = "ISO-8859-1", header=[0], na_values=['-'])

# %%
acs16.head()

# %%
acs16=acs16[['GEO.id','GEO.id2','GEO.display-label','HC01_VC85','HC01_VC131','HC03_VC131',
                'HC01_VC132','HC03_VC132','HC01_VC133','HC03_VC133','HC01_VC134','HC03_VC134']]
income16=acs16

# %%
income16.head()

# %%
income16.dtypes

# %%
income16.rename(columns={'GEO.display-label': 'city',
                         'HC01_VC85': 'median_income',
                         'HC01_VC131': 'insurance',
                         'HC01_VC132': 'private_insure',
                         'HC01_VC133': 'public_insure',
                         'HC01_VC134': 'no_insurance',

                         'HC03_VC131': 'insurance_pct',
                         'HC03_VC132': 'private_insure_pct',
                         'HC03_VC133': 'public_insure_pct',
                         'HC03_VC134': 'no_insurance_pct'  
                        }, 
                inplace=True)

# %%
income16.dtypes

# %%
income16['city']=income16.city.replace(' CDP, California', '', regex=True)

# %%
income16['city']=income16.city.replace(' city, California', '', regex=True)

# %%
income16['city']=income16.city.replace(' town, California', '', regex=True)

# %%
income16.head()

# %% [markdown]
# ## Join Demographics and income data

# %%
pop_data=demographic16.merge(income16, left_on='GEO.id', right_on='GEO.id', how='outer')
pop_data

# %%
list(pop_data.columns.values)

# %%
pop_data=pop_data.drop(columns=['GEO.id2_y','city_y'])

# %%
pop_data.rename(columns={'GEO.id': 'geoid',
                         'GEO.id2_x': 'geoid2',
                         'city_x': 'city'})

# %%
# Exported merged census data
pop_data.to_csv("pop_data16.csv", index=False)

# %% [markdown]
# ## Join Vaccine data to Census data

# %% [markdown]
# Join needs unique cities in the vaccine data to use as a key. Will need to figure out how to weight the different grade levels based on the census population numbers for age.

# %%
vac_pop_1718=vac_1718.merge(pop_data, left_on='CITY', right_on='city', how='outer')
vac_pop_1718
