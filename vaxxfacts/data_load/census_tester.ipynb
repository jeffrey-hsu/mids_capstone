# %% [markdown]
# ### Test Census API

# %%
import numpy as np
import pandas as pd

# %%
# !curl "https://api.census.gov/data/2016/acs/acs5/cprofile/?get=CP02_2007_2011_001E&for=county:*&in=state:06"
# Out:
# [["CP02_2007_2011_001E","state","county"],
# ["536160","06","001"],
# ["14283","06","005"],
# ["85219","06","007"],
# ["18865","06","009"],
# ["6989","06","011"],
# ["370925","06","013"],
# ["9818","06","015"],
# ["68812","06","017"],
# ["285338","06","019"],
# ["9483","06","021"],
# ["53724","06","023"],
# ["48117","06","025"],
# ["7910","06","027"],
# ["250999","06","029"],
# ["40716","06","031"],
# ["25654","06","033"],
# ["10097","06","035"],
# ["3218518","06","037"],
# ["42032","06","039"],
# ["102832","06","041"],
# ["7607","06","043"],
# ["34102","06","045"],
# ["74079","06","047"],
# ["3947","06","049"],
# ["5416","06","051"],
# ["125217","06","053"],
# ["49640","06","055"],
# ["41561","06","057"],
# ["987164","06","059"],
# ["130736","06","061"],
# ["9434","06","063"],
# ["672896","06","065"],
# ["510976","06","067"],
# ["16785","06","069"],
# ["598822","06","071"],
# ["1064048","06","073"],
# ["338366","06","075"],
# ["212902","06","077"],
# ["101993","06","079"],
# ...

# %%
# !curl "https://api.census.gov/data/2016/acs/acs5/?get=group(HC01)&for=county:*&in=state:06"
# Out:
# error: Group ' HC01 ' does not exist.
