# %% [markdown]
# ### Correlation vaxx rate v.s. census factors

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %matplotlib inline

# %%
df = pd.read_csv('../cleaning_etl/cleanjoin1718.csv')

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['facility_num', 'county', 'is_public', 'city', 'facility_name',
#        'enrollment', 'n', 'pct', 'vac_info_type', 'reported', 'geoid',
#        'geoid2', 'tot_pop', 'male', 'male_pct', 'female', 'female_pct',
#        'under_5', 'under_5_pct', '5_9', '5_9_pct', '10_14', '10_14_pct',
#        '15_19', '15_19_pct', '20_24', '20_24_pct', '25_34', '25_34_pct',
#        '35_44', '35_44_pct', '45_54', '45_54_pct', '55_59', '55_59_pct',
#        '60_64', '60_64_pct', '65_74', '65_74_pct', '75_84', '75_84_pct',
#        '85_over', '85_over_pct', 'median_age', 'median_age_pct',
#        'hispanic_latino', 'hispanic_latino_pct', 'white', 'white_pct', 'black',
#        'black_pct', 'aian', 'aian_pct', 'asian', 'asian_pct', 'nhopi',
#        'nhopi_pct', 'other', 'other_pct', 'median_income', 'insurance',
#        'insurance_pct', 'private_insure', 'private_insure_pct',
#        'public_insure', 'public_insure_pct', 'no_insurance',
#        'no_insurance_pct'],
#       dtype='object')
# (18433, 68)

# %%
df[:1]
# Out:
#    facility_num   county   is_public     city  \
# 0      10214883  Alameda  HEAD START  Alameda
#
#                                 facility_name  enrollment   n  pct  \
# 0  ALAMEDA HEAD START . ANGELA AGUILAR CENTER          63  61   98
#
#    vac_info_type reported        ...        other_pct  median_income  \
# 0  ChildCareData        Y        ...             12.5        83048.0
#
#    insurance  insurance_pct  private_insure  private_insure_pct  \
# 0    70366.0           92.7         58794.0                77.5
#
#    public_insure  public_insure_pct  no_insurance  no_insurance_pct
# 0        20088.0               26.5        5528.0               7.3
#
# [1 rows x 68 columns]

# %%
cols = [ 'enrollment', 'n', 'pct', 'tot_pop', 'male_pct', 'female_pct',
         'under_5_pct', '5_9_pct', '10_14_pct', '15_19_pct', '20_24_pct', '25_34_pct', '35_44_pct',
         '45_54_pct', '55_59_pct', '60_64_pct', '65_74_pct', '75_84_pct', '85_over_pct',
         'median_age', 'hispanic_latino_pct', 'white_pct', 'black_pct', 'aian_pct', 'asian_pct',
         'nhopi_pct', 'other_pct', 'median_income', 'insurance_pct',  'private_insure_pct',
         'public_insure_pct', 'no_insurance_pct']

df[cols].head()
# Out:
#    enrollment    n  pct  tot_pop  male_pct  female_pct  under_5_pct  5_9_pct  \
# 0          63   61   98  77409.0      48.7        51.3          5.9      6.0
# 1          47   44   95  77409.0      48.7        51.3          5.9      6.0
# 2          44   41   95  77409.0      48.7        51.3          5.9      6.0
# 3         109  107   99  77409.0      48.7        51.3          5.9      6.0
# 4         100   99   99  77409.0      48.7        51.3          5.9      6.0
#
#    10_14_pct  15_19_pct        ...         black_pct  aian_pct  asian_pct  \
# 0        5.1        4.5        ...               7.4       0.2       30.4
# 1        5.1        4.5        ...               7.4       0.2       30.4
# 2        5.1        4.5        ...               7.4       0.2       30.4
# 3        5.1        4.5        ...               7.4       0.2       30.4
# 4        5.1        4.5        ...               7.4       0.2       30.4
#
#    nhopi_pct  other_pct  median_income  insurance_pct  private_insure_pct  \
# 0        0.7       12.5        83048.0           92.7                77.5
# 1        0.7       12.5        83048.0           92.7                77.5
# 2        0.7       12.5        83048.0           92.7                77.5
# 3        0.7       12.5        83048.0           92.7                77.5
# 4        0.7       12.5        83048.0           92.7                77.5
#
#    public_insure_pct  no_insurance_pct
# 0               26.5               7.3
# 1               26.5               7.3
# 2               26.5               7.3
# 3               26.5               7.3
# 4               26.5               7.3
#
# [5 rows x 32 columns]

# %%
print(len(df[df.is_public == 'HEAD START'].is_public))
print(len(df[df.is_public == 'PUBLIC'].is_public))
print(len(df[df.is_public == 'PRIVATE'].is_public))
# Out:
# 1171
# 10501
# 6761

# %%
def plot_corr(df_corr,size=10):
    '''
    Args:
        - df_corr: pandas DataFrame of correlation
        - size: vertical and horizontal size of the plot
    '''
    corr = df_corr
    fig, ax = plt.subplots(figsize=(size, size))
    cmap = cm.get_cmap('jet', 30)
    cax = ax.imshow(corr, interpolation="nearest", cmap=cmap)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.xticks(rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    fig.colorbar(cax, ticks=[-1, -.8, -.6,-.4,-.2,0.0, .2, .4, .6, .8, 1])

plot_corr(df[cols].corr())

# %%
df_city1617 = pd.read_csv('../cleaning_etl/vac_pct_table1617.CSV')
df_pop1617 = pd.read_csv('../cleaning_etl/pop_data16.csv')

# %%
df_pop1617_subset = df_pop1617[['city'] + cols[3:]]

# %%
df_merge = df_city1617.merge(df_pop1617_subset, left_on=['city'], right_on=['city'], how='left')
df_merge.head()
# Out:
#    Unnamed: 0   county     city     vac_info_type        pct  tot_pop  \
# 0           0  Alameda  Alameda      7thGradeData  97.100000  77409.0
# 1           1  Alameda  Alameda     ChildCareData  95.923077  77409.0
# 2           2  Alameda  Alameda  KindergartenData  96.500000  77409.0
# 3           3  Alameda   Albany      7thGradeData  96.000000  19420.0
# 4           4  Alameda   Albany     ChildCareData  94.166667  19420.0
#
#    male_pct  female_pct  under_5_pct  5_9_pct        ...         black_pct  \
# 0      48.7        51.3          5.9      6.0        ...               7.4
# 1      48.7        51.3          5.9      6.0        ...               7.4
# 2      48.7        51.3          5.9      6.0        ...               7.4
# 3      48.4        51.6          7.7      7.9        ...               3.8
# 4      48.4        51.6          7.7      7.9        ...               3.8
#
#    aian_pct  asian_pct  nhopi_pct  other_pct  median_income  insurance_pct  \
# 0       0.2       30.4        0.7       12.5        83048.0           92.7
# 1       0.2       30.4        0.7       12.5        83048.0           92.7
# 2       0.2       30.4        0.7       12.5        83048.0           92.7
# 3       0.3       26.4        0.8       13.6        85458.0           95.4
# 4       0.3       26.4        0.8       13.6        85458.0           95.4
#
#    private_insure_pct  public_insure_pct  no_insurance_pct
# 0                77.5               26.5               7.3
# 1                77.5               26.5               7.3
# 2                77.5               26.5               7.3
# 3                82.8               20.7               4.6
# 4                82.8               20.7               4.6
#
# [5 rows x 34 columns]

# %%
plot_corr(df_merge[3:])

# %%
target_cols = ['tot_pop', 'male_pct', 'female_pct', 
                              'under_5_pct', '5_9_pct', '10_14_pct',
                              '15_19_pct', '20_24_pct', '25_34_pct', 
                              '35_44_pct', '45_54_pct', '55_59_pct', 
                              '60_64_pct', '65_74_pct', '75_84_pct', 
                              '85_over_pct', 'median_age', 'hispanic_latino_pct', 
                              'white_pct', 'black_pct', 'aian_pct', 'asian_pct', 
                              'nhopi_pct', 'other_pct', 'median_income',
                              'insurance_pct', 'private_insure_pct', 
                              'public_insure_pct', 'no_insurance_pct']


corr_ls = []
for i, col in enumerate(target_cols):
     corr_ls += [df_merge['pct'].corr(df_merge[col])]

corr_df = pd.DataFrame([corr_ls], index=np.arange(1), columns=target_cols)
corr_df
# Out:
#     tot_pop  male_pct  female_pct  under_5_pct   5_9_pct  10_14_pct  \
# 0  0.021459  0.045306   -0.045305     0.124376  0.089724   0.133004
#
#    15_19_pct  20_24_pct  25_34_pct  35_44_pct        ...         black_pct  \
# 0   0.113764   0.076606   0.079581    0.10045        ...          0.089036
#
#    aian_pct  asian_pct  nhopi_pct  other_pct  median_income  insurance_pct  \
# 0 -0.022543   0.102529    0.01693  -0.050848       0.018375      -0.081061
#
#    private_insure_pct  public_insure_pct  no_insurance_pct
# 0           -0.074052          -0.013692          0.081061
#
# [1 rows x 29 columns]

# %%
def plot_corr_1D(df_corr,size=10, show_color = 1):
    '''
    Args:
        - df_corr: pandas DataFrame of correlation
        - size: vertical and horizontal size of the plot
    '''
    corr = df_corr
    ncol = len(df_corr.columns)
    nrow = len(df_corr)
    fig, ax = plt.subplots(figsize=(size, size))
    cmap = cm.get_cmap('jet', 30)
    cax = ax.imshow(corr, interpolation="nearest", cmap=cmap)
    plt.xticks(range(ncol), corr.columns)
    plt.xticks(rotation=90)
    plt.yticks(range(nrow), ['pct'])
    if show_color:
        fig.colorbar(cax, orientation='horizontal', ticks = [-.4, -.3, -.2, -.1, 0.0, .1, .2, .3, .4])

plot_corr_1D(corr_df)

# %%
corr_df['white_pct']
# Out:
# 0   -0.413159
# Name: white_pct, dtype: float64

# %%
city_corr = pd.read_csv('../cleaning_etl/city_correlation.csv')
county_corr = pd.read_csv('../cleaning_etl/county_correlation.csv')

# %%
city_corr.head(3)
# Out:
#        city  enrollment  vaccinated school_year  year    vac_pct  \
# 0    Acampo       366.0       360.0   2011-2012  2012  98.360656
# 1     Acton       841.0       636.0   2011-2012  2012  75.624257
# 2  Adelanto      1500.0      1415.0   2011-2012  2012  94.333333
#
#               geoid  geoid2  tot_pop   male         ...           insurance  \
# 0  1600000US0600156  600156      462    324         ...                 377
# 1  1600000US0600212  600212     7117   3547         ...                6543
# 2  1600000US0600296  600296    31040  16275         ...               22321
#
#    insurance_pct  private_insure  private_insure_pct  public_insure  \
# 0           81.6             377                81.6              0
# 1           92.0            5676                79.8           1766
# 2           76.4           10474                35.9          13060
#
#    public_insure_pct  no_insurance  no_insurance_pct  hs_degree_pct  \
# 0                0.0            85              18.4           54.3
# 1               24.8           569               8.0           93.6
# 2               44.7          6888              23.6           67.4
#
#    bachelor_degree_pct
# 0                  0.0
# 1                 27.9
# 2                  7.4
#
# [3 rows x 68 columns]

# %%
cols = ['year', 'vac_pct', 'tot_pop', 'male_pct', 'female_pct', 'under_5_pct', '5_9_pct', '10_14_pct', '15_19_pct', 
        '20_24_pct', '25_34_pct', '35_44_pct', '45_54_pct', '55_59_pct', '60_64_pct',
        '65_74_pct', '75_84_pct', '85_over_pct', 'median_age', 'hispanic_latino_pct', 'mexican_pct',
        'white_pct', 'black_pct', 'aian_pct', 'asian_pct', 'nhopi_pct', 'other_pct', 'median_income',
        'insurance_pct', 'private_insure_pct', 'public_insure_pct', 'no_insurance_pct', 
        'hs_degree_pct', 'bachelor_degree_pct']
city_corr = city_corr[cols]

# %%
cols = ['year', 'vac_pct', 'tot_pop', 'male_pct', 'female_pct', 'under_5_pct', '5_9_pct', '10_14_pct', '15_19_pct', 
        '20_24_pct', '25_34_pct', '35_44_pct', '45_54_pct', '55_59_pct', '60_64_pct',
        '65_74_pct', '75_84_pct', '85_over_pct', 'median_age', 'hispanic_latino_pct', 'mexican_pct',
        'white_pct', 'black_pct', 'american_indian_alaskan_native_pct', 'asian_pct', 
        'native_hawaiian_pacific_islander_pct', 'other_pct', 
        'median_income', 'insurance_pct', 'private_insure_pct', 'public_insure_pct', 'no_insurance_pct', 
        'hs_degree_pct', 'bachelor_degree_pct']

city_corr.columns = cols

# %%
corr_dfs = pd.DataFrame(columns=[cols[0]] + cols[2:])
corr_dfs.loc[0] = [cols[0]] + cols[2:]
corr_dfs
# Out:
#    year  tot_pop  male_pct  female_pct  under_5_pct  5_9_pct  10_14_pct  \
# 0  year  tot_pop  male_pct  female_pct  under_5_pct  5_9_pct  10_14_pct
#
#    15_19_pct  20_24_pct  25_34_pct         ...           asian_pct  \
# 0  15_19_pct  20_24_pct  25_34_pct         ...           asian_pct
#
#    native_hawaiian_pacific_islander_pct  other_pct  median_income  \
# 0  native_hawaiian_pacific_islander_pct  other_pct  median_income
#
#    insurance_pct  private_insure_pct  public_insure_pct  no_insurance_pct  \
# 0  insurance_pct  private_insure_pct  public_insure_pct  no_insurance_pct
#
#    hs_degree_pct  bachelor_degree_pct
# 0  hs_degree_pct  bachelor_degree_pct
#
# [1 rows x 33 columns]

# %%
corr_dfs = pd.DataFrame(columns=[cols[0]] + cols[2:])
xcols = city_corr.columns[2:]
years = [2012, 2013, 2014, 2015, 2016, 2017]

show_col = 0
for i, y in enumerate(years):
    ls = []
    df = city_corr[city_corr['year'] == y]
    for xcol in xcols:
        ls.append(df['vac_pct'].corr(df[xcol]))
    corr_df = pd.DataFrame([ls], index=np.arange(1), columns=xcols)
    corr_dfs.loc[i] = [str(y)] + ls
    #corr_df_ls.append((y, corr_df))
    if y == 2017:
        show_col = 1
    plot_corr_1D(corr_df, size = 15, show_color = show_col)

# %%
corr_dfs.to_csv('./vac_pct_corr.csv')
corr_dfs
# Out:
#    year   tot_pop  male_pct  female_pct  under_5_pct   5_9_pct  10_14_pct  \
# 0  2012  0.078640  0.078623   -0.078623     0.160650  0.140793   0.152284
# 1  2013  0.067369  0.033110   -0.033087     0.216826  0.216173   0.237377
# 2  2014  0.070714  0.047270   -0.047270     0.254089  0.226729   0.220285
# 3  2015  0.046016 -0.026849    0.026854     0.294556  0.250608   0.204783
# 4  2016  0.057849 -0.033336    0.033354     0.204468  0.214975   0.189401
# 5  2017  0.069232  0.028295   -0.028294     0.109541  0.081445   0.136537
#
#    15_19_pct  20_24_pct  25_34_pct         ...           asian_pct  \
# 0   0.138756   0.125768   0.136672         ...            0.189001
# 1   0.167791   0.144915   0.100699         ...            0.173619
# 2   0.160321   0.162406   0.148346         ...            0.187155
# 3   0.171801   0.139773   0.153068         ...            0.162170
# 4   0.192553   0.159972   0.120583         ...            0.188324
# 5   0.111945   0.105807   0.085959         ...            0.165713
#
#    native_hawaiian_pacific_islander_pct  other_pct  median_income  \
# 0                              0.049382  -0.145012       0.045125
# 1                              0.040794  -0.091527       0.018990
# 2                             -0.020494  -0.058474       0.037303
# 3                             -0.012181  -0.058544       0.015603
# 4                              0.034992  -0.066952       0.050398
# 5                              0.012399  -0.034895       0.090178
#
#    insurance_pct  private_insure_pct  public_insure_pct  no_insurance_pct  \
# 0      -0.124017           -0.125729          -0.027748          0.124009
# 1      -0.144067           -0.135545          -0.032150          0.144067
# 2      -0.107956           -0.102635          -0.055442          0.107966
# 3      -0.083538           -0.102417          -0.028232          0.083538
# 4      -0.092326           -0.096989          -0.040464          0.092336
# 5      -0.022887            0.003945          -0.110902          0.022887
#
#    hs_degree_pct  bachelor_degree_pct
# 0      -0.254991            -0.093896
# 1      -0.312958            -0.144852
# 2      -0.296246            -0.127614
# 3      -0.283898            -0.127080
# 4      -0.268177            -0.098536
# 5      -0.085190             0.047912
#
# [6 rows x 33 columns]

# %%
def plot_corr_1D(df_corr_ls,size=10):
    '''
    Args:
        - df_corr_ls: list of (year, pandas DataFrame of correlation) tuples
        - size: vertical and horizontal size of the plot
    '''
    nplots = len(df_corr_ls)
    fig, axs = plt.subplots(nplots, 1, figsize=(size, size))
    images = []
    for k, v in enumerate(df_corr_ls):
        y = v[0]
        df_corr = v[1]
        ncol = len(df_corr.columns)
        nrow = len(df_corr)
        images.append(axs[k, 0].imshow(df_corr, interpolation="nearest"))
        #fig, ax = plt.subplots(figsize=(size, size))
    vmin = min(image.get_array().min() for image in images)
    vmax = max(image.get_array().max() for image in images)
    norm = colors.Normalize(vmin=vmin, vmax=vmax)
    for im in images:
        im.set_norm(norm)

    #cmap = cm.get_cmap('jet', 30)
    #cax = ax.imshow(corr, interpolation="nearest", cmap=cmap)
    plt.xticks(range(ncol), corr.columns)
    plt.xticks(rotation=90)
    plt.yticks(range(nrow), ['pct'])
    fig.colorbar(cax, orientation='vertical')

# %%
plot_corr_1D(df_corr_ls=corr_df_ls)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-cdaebe62b960> in <module>()
# ----> 1 plot_corr_1D(df_corr_ls=corr_df_ls)
#
# <ipython-input-88-d3a3ad59a5e4> in plot_corr_1D(df_corr_ls, size)
#      13         ncol = len(df_corr.columns)
#      14         nrow = len(df_corr)
# ---> 15         images.append(axs[k, 0].imshow(df_corr, interpolation="nearest"))
#      16         #fig, ax = plt.subplots(figsize=(size, size))
#      17     vmin = min(image.get_array().min() for image in images)
#
# IndexError: too many indices for array

# %%
def normalize(df):
    df_norm = pd.DataFrame(columns=df.columns)
    for col in df.columns:
        m = np.mean(df[col])
        sd = np.std(df[col])
        df_norm[col] = (df[col] - m)/sd
    return df_norm

# %%
cols = ['vac_pct'] + list(city_corr.columns)[7:]
df = city_corr[cols]
df = df.dropna()
df_norm = normalize(df[df.columns[1:]])
df_norm['vac_pct'] = df['vac_pct']/100

# %%
df_norm.head()
# Out:
# Empty DataFrame
# Columns: [geoid2, tot_pop, male, male_pct, female, female_pct, under_5, under_5_pct, 5_9, 5_9_pct, 10_14, 10_14_pct, 15_19, 15_19_pct, 20_24, 20_24_pct, 25_34, 25_34_pct, 35_44, 35_44_pct, 45_54, 45_54_pct, 55_59, 55_59_pct, 60_64, 60_64_pct, 65_74, 65_74_pct, 75_84, 75_84_pct, 85_over, 85_over_pct, median_age, median_age_pct, hispanic_latino, hispanic_latino_pct, mexican, mexican_pct, white, white_pct, black, black_pct, aian, aian_pct, asian, asian_pct, nhopi, nhopi_pct, other, other_pct, median_income, insurance, insurance_pct, private_insure, private_insure_pct, public_insure, public_insure_pct, no_insurance, no_insurance_pct, hs_degree_pct, bachelor_degree_pct, vac_pct]
# Index: []
#
# [0 rows x 62 columns]

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
cols = ['vac_pct'] + list(city_corr.columns)[7:]
df = city_corr[cols]
df = df.dropna()
da = df.values
da_norm = scaler.fit_transform(df)
df = pd.DataFrame(da_norm, columns=cols)

#city_corr['vac_pct_norm'] = (city_corr['vac_pact'] - np.avg(city_corr['vac_pact'])) / np.var(city_corr['vac_pact'])

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
train, test = train_test_split(df, test_size = 0.25)
train_X = np.array(train[train.columns[1:]])
train_Y = np.array(train[train.columns[0]])
test_X = np.array(test[test.columns[1:]])
test_Y = np.array(test[test.columns[0]])
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty='l2')
lr.fit(train_X, train_Y)

print("training score: ", lr.score(train_X, train_Y))
print("test score: ", lr.score(test_X, test_Y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-e909d74dd824> in <module>()
#       2
#       3 lr = LogisticRegression(penalty='l2')
# ----> 4 lr.fit(train_X, train_Y)
#       5
#       6 lr.score(train_X, train_Y)
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
#    1216                          order="C")
# -> 1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#    1219         n_samples, n_features = X.shape
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'

# %%
train_X.shape
# Out:
# (4365, 28)
